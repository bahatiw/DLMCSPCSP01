# %% [markdown]
# # Import libraries we need for this project

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn import preprocessing
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
from sklearn.metrics import jaccard_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss
from sklearn.metrics import confusion_matrix, accuracy_score
import sklearn.metrics as metrics
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from time import time

# %% [markdown]
# ## Version of modules used

# %% [markdown]
# ### Specify the file contain our data.

# %%
filename ="Weather_Data.csv"

# %% [markdown]
# ### Read This into a Panda DataFrame

# %%
df = pd.read_csv("Weather_Data.csv")

# %%
print('Loaded {} records from {}.\n'.format(len(df), filename))
# Out:
# Loaded 3271 records from Weather_Data.csv.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           3271 non-null   object
#  1   MinTemp        3271 non-null   float64
#  2   MaxTemp        3271 non-null   float64
#  3   Rainfall       3271 non-null   float64
#  4   Evaporation    3271 non-null   float64
#  5   Sunshine       3271 non-null   float64
#  6   WindGustDir    3271 non-null   object
#  7   WindGustSpeed  3271 non-null   int64
#  8   WindDir9am     3271 non-null   object
#  9   WindDir3pm     3271 non-null   object
#  10  WindSpeed9am   3271 non-null   int64
#  11  WindSpeed3pm   3271 non-null   int64
#  12  Humidity9am    3271 non-null   int64
#  13  Humidity3pm    3271 non-null   int64
#  14  Pressure9am    3271 non-null   float64
#  15  Pressure3pm    3271 non-null   float64
#  16  Cloud9am       3271 non-null   int64
#  17  Cloud3pm       3271 non-null   int64
#  18  Temp9am        3271 non-null   float64
#  19  Temp3pm        3271 non-null   float64
#  20  RainToday      3271 non-null   object
#  21  RainTomorrow   3271 non-null   object
# dtypes: float64(9), int64(7), object(6)
# memory usage: 562.3+ KB
# None

# %% [markdown]
# ### Check that we have loaded the correct data

# %%
df.head()
# Out:
#        Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0  2/1/2008     19.5     22.4      15.6          6.2       0.0           W
# 1  2/2/2008     19.5     25.6       6.0          3.4       2.7           W
# 2  2/3/2008     21.6     24.5       6.6          2.4       0.1           W
# 3  2/4/2008     20.2     22.8      18.8          2.2       0.0           W
# 4  2/5/2008     19.7     25.7      77.4          4.8       0.0           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0             41          S        SSW  ...           92           84
# 1             41          W          E  ...           83           73
# 2             41        ESE        ESE  ...           88           86
# 3             41        NNE          E  ...           83           90
# 4             41        NNE          W  ...           88           74
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1017.6       1017.4         8         8     20.7     20.9        Yes
# 1       1017.9       1016.4         7         7     22.4     24.8        Yes
# 2       1016.7       1015.6         7         8     23.5     23.0        Yes
# 3       1014.2       1011.8         8         8     21.4     20.9        Yes
# 4       1008.3       1004.8         8         8     22.5     25.5        Yes
#
#    RainTomorrow
# 0           Yes
# 1           Yes
# 2           Yes
# 3           Yes
# 4           Yes
#
# [5 rows x 22 columns]

# %% [markdown]
# ### For Regression we need to convert some categorical data to binary in order for the model to work. In our case RainToday,WindGustDir,WindDir9am,WindDir3pm. We perform one hot encoding

# %%
df_processed = pd.get_dummies(data=df, columns=['RainToday', 'WindGustDir', 'WindDir9am', 'WindDir3pm'])

# %% [markdown]
# ## Reconfirm our data is in shape

# %%
df_processed.head()
# Out:
#        Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0  2/1/2008     19.5     22.4      15.6          6.2       0.0             41
# 1  2/2/2008     19.5     25.6       6.0          3.4       2.7             41
# 2  2/3/2008     21.6     24.5       6.6          2.4       0.1             41
# 3  2/4/2008     20.2     22.8      18.8          2.2       0.0             41
# 4  2/5/2008     19.7     25.7      77.4          4.8       0.0             41
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  ...  WindDir3pm_NNW  \
# 0            17            20           92  ...           False
# 1             9            13           83  ...           False
# 2            17             2           88  ...           False
# 3            22            20           83  ...           False
# 4            11             6           88  ...           False
#
#    WindDir3pm_NW  WindDir3pm_S  WindDir3pm_SE  WindDir3pm_SSE  WindDir3pm_SSW  \
# 0          False         False          False           False            True
# 1          False         False          False           False           False
# 2          False         False          False           False           False
# 3          False         False          False           False           False
# 4          False         False          False           False           False
#
#    WindDir3pm_SW WindDir3pm_W  WindDir3pm_WNW  WindDir3pm_WSW
# 0          False        False           False           False
# 1          False        False           False           False
# 2          False        False           False           False
# 3          False        False           False           False
# 4          False         True           False           False
#
# [5 rows x 68 columns]

# %% [markdown]
# ### We also change the RainTommorow Column to binary from "Yes" and "No" for regression

# %%
df_processed.replace(['No', 'Yes'], [0,1], inplace=True)
# Out:
# C:\Users\Admin.DESKTOP-QVO174E\AppData\Local\Temp\ipykernel_10544\1204962372.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_processed.replace(['No', 'Yes'], [0,1], inplace=True)

# %% [markdown]
# # Prepare our data for Training and Testing

# %%
df_processed.drop('Date',axis=1,inplace=True)

# %%
df_processed = df_processed.astype(float)

# %%
print(df_processed.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 67 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MinTemp          3271 non-null   float64
#  1   MaxTemp          3271 non-null   float64
#  2   Rainfall         3271 non-null   float64
#  3   Evaporation      3271 non-null   float64
#  4   Sunshine         3271 non-null   float64
#  5   WindGustSpeed    3271 non-null   float64
#  6   WindSpeed9am     3271 non-null   float64
#  7   WindSpeed3pm     3271 non-null   float64
#  8   Humidity9am      3271 non-null   float64
#  9   Humidity3pm      3271 non-null   float64
#  10  Pressure9am      3271 non-null   float64
#  11  Pressure3pm      3271 non-null   float64
#  12  Cloud9am         3271 non-null   float64
#  13  Cloud3pm         3271 non-null   float64
#  14  Temp9am          3271 non-null   float64
#  15  Temp3pm          3271 non-null   float64
#  16  RainTomorrow     3271 non-null   float64
#  17  RainToday_No     3271 non-null   float64
#  18  RainToday_Yes    3271 non-null   float64
#  19  WindGustDir_E    3271 non-null   float64
#  20  WindGustDir_ENE  3271 non-null   float64
#  21  WindGustDir_ESE  3271 non-null   float64
#  22  WindGustDir_N    3271 non-null   float64
#  23  WindGustDir_NE   3271 non-null   float64
#  24  WindGustDir_NNE  3271 non-null   float64
#  25  WindGustDir_NNW  3271 non-null   float64
#  26  WindGustDir_NW   3271 non-null   float64
#  27  WindGustDir_S    3271 non-null   float64
#  28  WindGustDir_SE   3271 non-null   float64
#  29  WindGustDir_SSE  3271 non-null   float64
#  30  WindGustDir_SSW  3271 non-null   float64
#  31  WindGustDir_SW   3271 non-null   float64
#  32  WindGustDir_W    3271 non-null   float64
#  33  WindGustDir_WNW  3271 non-null   float64
#  34  WindGustDir_WSW  3271 non-null   float64
#  35  WindDir9am_E     3271 non-null   float64
#  36  WindDir9am_ENE   3271 non-null   float64
#  37  WindDir9am_ESE   3271 non-null   float64
#  38  WindDir9am_N     3271 non-null   float64
#  39  WindDir9am_NE    3271 non-null   float64
#  40  WindDir9am_NNE   3271 non-null   float64
#  41  WindDir9am_NNW   3271 non-null   float64
#  42  WindDir9am_NW    3271 non-null   float64
#  43  WindDir9am_S     3271 non-null   float64
#  44  WindDir9am_SE    3271 non-null   float64
#  45  WindDir9am_SSE   3271 non-null   float64
#  46  WindDir9am_SSW   3271 non-null   float64
#  47  WindDir9am_SW    3271 non-null   float64
#  48  WindDir9am_W     3271 non-null   float64
#  49  WindDir9am_WNW   3271 non-null   float64
#  50  WindDir9am_WSW   3271 non-null   float64
#  51  WindDir3pm_E     3271 non-null   float64
#  52  WindDir3pm_ENE   3271 non-null   float64
#  53  WindDir3pm_ESE   3271 non-null   float64
#  54  WindDir3pm_N     3271 non-null   float64
#  55  WindDir3pm_NE    3271 non-null   float64
#  56  WindDir3pm_NNE   3271 non-null   float64
#  57  WindDir3pm_NNW   3271 non-null   float64
#  58  WindDir3pm_NW    3271 non-null   float64
#  59  WindDir3pm_S     3271 non-null   float64
#  60  WindDir3pm_SE    3271 non-null   float64
#  61  WindDir3pm_SSE   3271 non-null   float64
#  62  WindDir3pm_SSW   3271 non-null   float64
#  63  WindDir3pm_SW    3271 non-null   float64
#  64  WindDir3pm_W     3271 non-null   float64
#  65  WindDir3pm_WNW   3271 non-null   float64
#  66  WindDir3pm_WSW   3271 non-null   float64
# dtypes: float64(67)
# memory usage: 1.7 MB
# None

# %%
with pd.option_context('float_format', '{:.2f}'.format): 
    print( df_processed.describe() )
# Out:
#        MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# count  3271.00  3271.00   3271.00      3271.00   3271.00        3271.00
# mean     14.88    23.01      3.34         5.18      7.17          41.48
# std       4.55     4.48      9.92         2.76      3.82          10.81
# min       4.30    11.70      0.00         0.00      0.00          17.00
# 25%      11.00    19.60      0.00         3.20      4.25          35.00
# 50%      14.90    22.80      0.00         4.80      8.30          41.00
# 75%      18.80    26.00      1.40         7.00     10.20          44.00
# max      27.60    45.80    119.40        18.40     13.60          96.00
#
#        WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  \
# count       3271.00       3271.00      3271.00      3271.00  ...
# mean          15.08         19.29        68.24        54.70  ...
# std            7.04          7.45        15.09        16.28  ...
# min            0.00          0.00        19.00        10.00  ...
# 25%           11.00         15.00        58.00        44.00  ...
# 50%           15.00         19.00        69.00        56.00  ...
# 75%           20.00         24.00        80.00        64.00  ...
# max           54.00         57.00       100.00        99.00  ...
#
#        WindDir3pm_NNW  WindDir3pm_NW  WindDir3pm_S  WindDir3pm_SE  \
# count         3271.00        3271.00       3271.00        3271.00
# mean             0.01           0.02          0.07           0.07
# std              0.11           0.13          0.26           0.25
# min              0.00           0.00          0.00           0.00
# 25%              0.00           0.00          0.00           0.00
# 50%              0.00           0.00          0.00           0.00
# 75%              0.00           0.00          0.00           0.00
# max              1.00           1.00          1.00           1.00
#
#        WindDir3pm_SSE  WindDir3pm_SSW  WindDir3pm_SW  WindDir3pm_W  \
# count         3271.00         3271.00        3271.00       3271.00
# mean             0.08            0.05           0.01          0.06
# std              0.28            0.21           0.11          0.24
# min              0.00            0.00           0.00          0.00
# 25%              0.00            0.00           0.00          0.00
# 50%              0.00            0.00           0.00          0.00
# 75%              0.00            0.00           0.00          0.00
# max              1.00            1.00           1.00          1.00
#
#        WindDir3pm_WNW  WindDir3pm_WSW
# count         3271.00         3271.00
# mean             0.06            0.03
# std              0.23            0.18
# min              0.00            0.00
# 25%              0.00            0.00
# 50%              0.00            0.00
# 75%              0.00            0.00
# max              1.00            1.00
#
# [8 rows x 67 columns]

# %% [markdown]
# ## Use histograms to visualize the distribution of various features

# %%
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

df.hist(figsize=(20,15));
plt.figure();

# %% [markdown]
# ## Show correlations with RainTommorow

# %%
print('Pearson correlations with RainTommorow')
corr_matrix = df_processed.corr()
corr_matrix['RainTomorrow'].sort_values(ascending=False)
# Out:
# Pearson correlations with RainTommorow
# RainTomorrow     1.000000
# Humidity3pm      0.477580
# Cloud3pm         0.415801
# RainToday_Yes    0.346207
# Cloud9am         0.338545
#                    ...
# WindDir3pm_E    -0.106425
# MaxTemp         -0.152525
# Temp3pm         -0.190583
# RainToday_No    -0.346207
# Sunshine        -0.529112
# Name: RainTomorrow, Length: 67, dtype: float64

# %% [markdown]
# ## Analyze cross correlations

# %%
# Specify size and title for the visualization
f, axes = plt.subplots(figsize=(20, 20))
plt.title('All Correlations',fontsize=32)

# For the purpose of visualization, we'll use a different order for the features.
# We'll start with RainTommorow, to make it easier to compare all other features with it.
features = ['RainTomorrow','Humidity3pm','Cloud3pm',
            'RainToday_Yes','Cloud9am','MaxTemp','Rainfall','Evaporation','Temp3pm' ]

# Use Seaborn library to plot the correlation matrix as a heatmap
sns.heatmap(df_processed[features].corr(),
           linewidths = 3.0,
           square = True,
           cmap = 'Greens',
           linecolor='w',
           annot=True,
           annot_kws={'size':11},
           cbar_kws={'shrink': .5});

# %%
x_values = df_processed.drop(columns='RainTomorrow', axis=1)

# %%
y_values = df_processed['RainTomorrow']

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ### We split the data for training and testing set to make it 20% for testing and 80% for Training

# %%
x_train, x_test, y_train, y_test =  train_test_split(x_values,y_values , random_state=10,test_size=0.2, shuffle=True)

# %%
# Create a linear regression model
regressor = LinearRegression()

# %%
# Fit the model using training data and labels
start = time()
regressor.fit(x_train, y_train);
end=time()
train_time = (end - start) * 1000
print('Model took {:,.2f} milliseconds to fit.'.format(train_time))
# Out:
# Model took 1,741.04 milliseconds to fit.

# %% [markdown]
# # Evaluate the model using the test dataset

# %%
# Evaluate the model's performance using test data and labels
score = regressor.score(x_test, y_test)
'Score: {}%'.format(int(round(score * 100)))
# Out:
# 'Score: 43%'

# %% [markdown]
# ## Compare predicted values to actual values

# %%
predictions = regressor.predict(x_test)
LinearReg_diff = pd.DataFrame({'Actual value': y_test, 'Predicted value': predictions})
LinearReg_diff
# Out:
#       Actual value  Predicted value
# 3066           0.0         0.131838
# 2456           0.0         0.276185
# 1629           1.0         0.978189
# 838            1.0         0.287457
# 2506           0.0         0.132414
# ...            ...              ...
# 2632           1.0         0.264843
# 1725           0.0         0.175158
# 1158           1.0         0.706317
# 1661           0.0         0.173841
# 68             1.0         0.344310
#
# [655 rows x 2 columns]

# %%
predicted = regressor.predict(x_test)
predictions ['yvalues'] = y_test.copy()
predictions['predicted'] = predicted

# View examples comparing actual prices to predicted prices
#with pd.option_context('float_format', '{:,.2f}'.format): print( predictions.head(10) )
# Out:
#   Cell In[50], line 7
#     print(predictions['predicted'] '\n')
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ## Outliers

# %%
feature_list = ['RainTomorrow','Humidity3pm','Cloud3pm',
            'RainToday_Yes','Cloud9am','MaxTemp','Rainfall','Evaporation','Temp3pm' ]

for feature in feature_list:
    plt.figure(figsize=(20,2))
    bplot = sns.boxplot(x=feature, data=df_processed, orient="h", fliersize=7)

# %% [markdown]
# ## Examine data values in the outliers

# %%
# Humidity is greater than 80
x_train.loc[x_train['Humidity3pm'] > 80]
# Out:
#       MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 1320     14.8     18.3      38.8          7.4       0.1           48.0
# 373      17.9     19.4       3.4          1.6       0.0           41.0
# 3253     12.4     18.1      61.0          1.8       1.3           44.0
# 27       17.9     21.4       4.2          4.2       0.0           41.0
# 1010     21.7     26.4       0.0          7.6       3.9           52.0
# ...       ...      ...       ...          ...       ...            ...
# 780      20.5     21.3       4.0          4.8       0.0           41.0
# 2904     14.5     19.5       0.4          0.8       0.0           52.0
# 1419     18.6     20.9      16.0          4.6       0.0           65.0
# 2967     11.8     14.7       2.4          3.2       0.0           43.0
# 2009     18.7     21.5       0.6          3.6       0.0           35.0
#
#       WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  \
# 1320          19.0          24.0         93.0         86.0  ...
# 373            6.0          19.0         94.0         89.0  ...
# 3253          17.0          15.0         91.0         84.0  ...
# 27            20.0           9.0         77.0         88.0  ...
# 1010           4.0           6.0         72.0         91.0  ...
# ...            ...           ...          ...          ...  ...
# 780            4.0           9.0         92.0         88.0  ...
# 2904          13.0          20.0         81.0         89.0  ...
# 1419          17.0          20.0         88.0         83.0  ...
# 2967          11.0           9.0         79.0         90.0  ...
# 2009           6.0          13.0         85.0         88.0  ...
#
#       WindDir3pm_NNW  WindDir3pm_NW  WindDir3pm_S  WindDir3pm_SE  \
# 1320             0.0            0.0           0.0            0.0
# 373              0.0            0.0           0.0            0.0
# 3253             0.0            0.0           1.0            0.0
# 27               0.0            0.0           0.0            0.0
# 1010             1.0            0.0           0.0            0.0
# ...              ...            ...           ...            ...
# 780              0.0            0.0           0.0            0.0
# 2904             0.0            0.0           0.0            0.0
# 1419             0.0            0.0           0.0            1.0
# 2967             0.0            0.0           0.0            0.0
# 2009             0.0            0.0           0.0            0.0
#
#       WindDir3pm_SSE  WindDir3pm_SSW  WindDir3pm_SW  WindDir3pm_W  \
# 1320             1.0             0.0            0.0           0.0
# 373              0.0             1.0            0.0           0.0
# 3253             0.0             0.0            0.0           0.0
# 27               0.0             0.0            0.0           0.0
# 1010             0.0             0.0            0.0           0.0
# ...              ...             ...            ...           ...
# 780              0.0             1.0            0.0           0.0
# 2904             0.0             0.0            0.0           0.0
# 1419             0.0             0.0            0.0           0.0
# 2967             0.0             0.0            0.0           0.0
# 2009             0.0             0.0            0.0           0.0
#
#       WindDir3pm_WNW  WindDir3pm_WSW
# 1320             0.0             0.0
# 373              0.0             0.0
# 3253             0.0             0.0
# 27               0.0             0.0
# 1010             0.0             0.0
# ...              ...             ...
# 780              0.0             0.0
# 2904             0.0             0.0
# 1419             0.0             0.0
# 2967             0.0             0.0
# 2009             0.0             0.0
#
# [170 rows x 66 columns]

# %% [markdown]
# ## Drop outliers from the training dataset

# %%
# Keep only rows with humidity is less than 80
y_train = y_train.loc[df_processed['Humidity3pm'] <= 80]
x_train = x_train.loc[x_train['Humidity3pm'] <= 80]
print(f'{len(x_train):6d} rows remain after dropping those with humidity more than 80')
# Out:
#   2446 rows remain after dropping those with humidity more than 80

# %% [markdown]
# ## Show statistics for the training features

# %%
with pd.option_context('float_format', '{:.2f}'.format):
    print(x_train['Humidity3pm'].describe(), '\n')
# Out:
# count   2446.00
# mean      52.33
# std       14.07
# min       10.00
# 25%       43.00
# 50%       55.00
# 75%       62.00
# max       80.00
# Name: Humidity3pm, dtype: float64

# %%
# Fit the model using training data and labels
start = time()
regressor.fit(x_train, y_train);
end=time()
train_time = (end - start) * 1000
print('Model took {:,.2f} milliseconds to fit.'.format(train_time))
# Out:
# Model took 54.99 milliseconds to fit.

# %%
# Evaluate the model's performance using test data and labels
score = regressor.score(x_test, y_test)
'Score: {}%'.format(int(round(score * 100)))
# Out:
# 'Score: 41%'

# %%
LinearRegression_MAE = metrics.mean_absolute_error(y_test, predictions)
LinearRegression_MSE = metrics.mean_squared_error(y_test, predictions)
LinearRegression_R2 = np.sqrt(metrics.mean_squared_error(y_test, predictions))
Report =  pd.DataFrame({
    'Metric': ['Mean Absolute Error (MAE)', 'Mean Squared Error (MSE)', 'R-squared (R²)'],
    'Value': [LinearRegression_MAE, LinearRegression_MSE, LinearRegression_R2]
})
Report
# Out:
#                       Metric     Value
# 0  Mean Absolute Error (MAE)  0.256318
# 1   Mean Squared Error (MSE)  0.115721
# 2             R-squared (R²)  0.340177

# %% [markdown]
# ## Random Forests

# %%
# Create a model using the random forest algorithm.

rnd_forest = RandomForestRegressor(n_estimators=100,random_state=0)

start = time()
rnd_forest.fit(x_train, y_train.values.ravel())
end=time()
train_time = (end - start) * 1000
print('Model took {:,.2f} milliseconds to fit.'.format(train_time))

score = rnd_forest.score(x_test, y_test)
print('Score: {}%'.format(int(round(score * 100))))
# Out:
# Model took 4,337.80 milliseconds to fit.
# Score: 39%
